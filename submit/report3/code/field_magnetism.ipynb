# %%
import numpy as np
from importlib import reload

import tool
reload(tool)
from tool import *

# %% [markdown]
# ## 印加磁場の符号に対する応答(温度変化)

# %%
file = "./data/magnetism/test0"
param = {"system": (3, 3, 3), "filename": f"{file}.dat", "nh": 30, "h_max": 10., "h_min": -3.}
magnetic(**param)
mc_plot_m(f"{file}.dat", f"{file}.pdf")
# Out:
# ...
# h = 10.0
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# ..............................
# ...
# finish
# Output results into './data/magnetism/test0.dat'

# %%
file = "./data/magnetism/test1"
param = {"system": (3, 3, 3), "filename": f"{file}.dat", "nh": 30, "J": 0.5, "h_max": 10., "h_min": -3.}
magnetic(**param)
mc_plot_m(f"{file}.dat", f"{file}.pdf")
# Out:
# ...
# h = 10.0
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# ..............................
# ...
# finish
# Output results into './data/magnetism/test1.dat'

# %%
file = "./data/magnetism/test9"
param = {"system": (3, 3, 3), "filename": f"{file}.dat", "nh": 10, "J": 0.5, "h_max": 10., "h_min": -3., "t": 2}
magnetic(**param)
mc_plot_m(f"{file}.dat", f"{file}.pdf")
# Out:
# ...
# h = 10.0
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# ..........
# ...
# finish
# Output results into './data/magnetism/test9.dat'

# %%
file = "./data/magnetism/test2"
param = {"system": (3, 3, 3), "filename": f"{file}.dat", "nh": 30, "J": -1., "h_max": 10., "h_min": -3.}
magnetic(**param)
mc_plot_m(f"{file}.dat", f"{file}.pdf")
# Out:
# ...
# h = 10.0
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# ..............................
# ...
# finish
# Output results into './data/magnetism/test2.dat'

# %%
file = "./data/magnetism/test3"
param = {"system": (3, 3, 3), "filename": f"{file}.dat", "nh": 30, "J": -0.5, "h_max": 10., "h_min": -3.}
magnetic(**param)
mc_plot_m(f"{file}.dat", f"{file}.pdf")
# Out:
# ...
# h = 10.0
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# ..............................
# ...
# finish
# Output results into './data/magnetism/test3.dat'

# %%
file = "./data/magnetism/test8"
param = {"system": (3, 3, 3), "filename": f"{file}.dat", "nh": 30, "J": -1., "h_max": 10., "h_min": -3., "t": 300}
magnetic(**param)
mc_plot_m(f"{file}.dat", f"{file}.pdf")
# Out:
# ...
# h = 10.0
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# ..............................
# ...
# finish
# Output results into './data/magnetism/test8.dat'

# %%
file = "./data/magnetism/test7"
param = {"system": (3, 3, 3), "filename": f"{file}.dat", "nh": 30, "J": 0., "h_max": 10., "h_min": -3., "t": 300}
magnetic(**param)
mc_plot_m(f"{file}.dat", f"{file}.pdf")
# Out:
# ...
# h = 10.0
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# ..............................
# ...
# finish
# Output results into './data/magnetism/test7.dat'

# %%
file = "./data/magnetism/test4"
param = {"system": (3, 3, 3), "filename": f"{file}.dat", "nh": 30, "J": 0., "h_max": 10., "h_min": -3.}
magnetic(**param)
mc_plot_m(f"{file}.dat", f"{file}.pdf")
# Out:
# ...
# h = 10.0
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# ..............................
# ...
# finish
# Output results into './data/magnetism/test4.dat'

# %%
file = "./data/magnetism/test5"
param = {"system": (5, 5, 5), "filename": f"{file}.dat", "nh": 30, "J": 0., "h_max": 10., "h_min": -3.}
magnetic(**param)
mc_plot_m(f"{file}.dat", f"{file}.pdf")
# Out:
# ...
# h = 10.0
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# ..............................
# ...
# finish
# Output results into './data/magnetism/test5.dat'
