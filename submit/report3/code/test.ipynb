# %%
import numpy as np
from monte_carlo import *
from main import main, mc_plot_m

# %% [markdown]
# ## 一次元イジングモデル: 誤差解析

# %%
param = {"system": (10,), "filename": "./data/system_5.5_meas1000.dat", "nt": 30, "tmax": 3.}
main(**param)
mc_plot_m(param["filename"])
# Out:
# ...
# T = 0.5
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [-0.1087]
# std : [0.71189976]
#
# ...
# T = 0.5862068965517242
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.2181]
# std : [0.44520201]
#
# ...
# T = 0.6724137931034483
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.05556]
# std : [0.38594469]
#
# ...
# T = 0.7586206896551724
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [-0.16826]
# std : [0.28252494]
#
# ...
# T = 0.8448275862068966
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.0381]
# std : [0.10511431]
#
# ...
# T = 0.9310344827586208
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.03818]
# std : [0.09521758]
#
# ...
# T = 1.0172413793103448
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [-0.00326]
# std : [0.05599107]
#
# ...
# T = 1.103448275862069
# Initializing MC...
# Warming up...
# ...

# %%
param = {"system": (100,), "filename": "./data/system_5.5_mes5000.dat", "nt": 30, "tmax": 3.}
main(**param)
mc_plot_m(param["filename"])
# Out:
# ...
# T = 0.5
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [-0.110232]
# std : [0.37440921]
#
# ...
# T = 0.5862068965517242
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [-0.038152]
# std : [0.25822239]
#
# ...
# T = 0.6724137931034483
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.009858]
# std : [0.13843774]
#
# ...
# T = 0.7586206896551724
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.077122]
# std : [0.05680771]
#
# ...
# T = 0.8448275862068966
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [-0.019176]
# std : [0.08178943]
#
# ...
# T = 0.9310344827586208
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.007492]
# std : [0.04932067]
#
# ...
# T = 1.0172413793103448
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [5.2e-05]
# std : [0.01994472]
#
# ...
# T = 1.103448275862069
# Initializing MC...
# ...

# %% [markdown]
# ## 二次元イジングモデル

# %%
param = {"system": (5, 5), "filename": "./data/system2d_5.5.dat", "nt": 30, "tmax": 3.}
main(**param)
mc_plot_m(param["filename"])
# Out:
# ...
# T = 0.5
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [1.]
# std : [0.]
#
# ...
# T = 0.5862068965517242
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.999992]
# std : [2.4e-05]
#
# ...
# T = 0.6724137931034483
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.999984]
# std : [3.2e-05]
#
# ...
# T = 0.7586206896551724
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.999912]
# std : [0.00012106]
#
# ...
# T = 0.8448275862068966
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.999824]
# std : [0.00014221]
#
# ...
# T = 0.9310344827586208
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.999568]
# std : [0.00023515]
#
# ...
# T = 1.0172413793103448
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.999184]
# std : [0.0003216]
#
# ...
# T = 1.103448275862069
# Initializing MC...
# Warming up...
# ...

# %%
param = {"system": (30, 30), "filename": "./data/system2d_5.5_nbin30.dat", "nt": 30, "tmax": 3.0}
main(**param)
mc_plot_m(param["filename"])
# Out:
# ...
# T = 0.5
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [1.]
# std : [0.]
#
# ...
# T = 0.5862068965517242
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.99999867]
# std : [1.47405546e-06]
#
# ...
# T = 0.6724137931034483
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.99998733]
# std : [3.85541146e-06]
#
# ...
# T = 0.7586206896551724
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.99994867]
# std : [8.45905169e-06]
#
# ...
# T = 0.8448275862068966
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.99984533]
# std : [1.34879919e-05]
#
# ...
# T = 0.9310344827586208
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.99959]
# std : [1.80328918e-05]
#
# ...
# T = 1.0172413793103448
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.99914467]
# std : [5.1269802e-05]
#
# ...
# T = 1.103448275862069
# ...

# %% [markdown]
# ## 3次元イジングモデル

# %%
param = {"system": (5, 5, 5), "filename": "./data/system3d_5.5_nbin5.dat", "nt": 30, "tmax": 5.0}
main(**param)
mc_plot_m(param["filename"])
# Out:
# ...
# T = 0.5
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [1.]
# std : [0.]
#
# ...
# T = 0.6551724137931034
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [1.]
# std : [0.]
#
# ...
# T = 0.8103448275862069
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [1.]
# std : [0.]
#
# ...
# T = 0.9655172413793104
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.9999968]
# std : [6.4e-06]
#
# ...
# T = 1.1206896551724137
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.9999632]
# std : [2.2683915e-05]
#
# ...
# T = 1.2758620689655173
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.9998592]
# std : [3.9060978e-05]
#
# ...
# T = 1.4310344827586208
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.9995904]
# std : [6.52674498e-05]
#
# ...
# T = 1.5862068965517242
# Initializing MC...
# Warming up...
# ...

# %%
param = {"system": (10, 10, 10), "filename": "./data/system3d_5.5_nbin10.dat", "nt": 30, "tmin":3.0, "tmax": 6.0}
main(**param)
mc_plot_m(param["filename"])
# Out:
# ...
# T = 3.0
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.9456116]
# std : [0.000465]
#
# ...
# T = 3.103448275862069
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.9353282]
# std : [0.0004563]
#
# ...
# T = 3.206896551724138
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.9235346]
# std : [0.00060145]
#
# ...
# T = 3.310344827586207
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.9100078]
# std : [0.00072421]
#
# ...
# T = 3.413793103448276
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.8947586]
# std : [0.00090972]
#
# ...
# T = 3.5172413793103448
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.8771542]
# std : [0.00116309]
#
# ...
# T = 3.6206896551724137
# Initializing MC...
# Warming up...
#   obtained data shape: (10, 1)
# mean: [0.8566166]
# std : [0.00128274]
#
# ...
# T = 3.7241379310344827
# Initializing MC...
# ...

# %%
param = {"system": (30, 30, 30), "filename": "./data/system3d_5.5_nbin30.dat", "nt": 30, "tmin":3.5, "tmax": 6.5}
main(**param)
mc_plot_m(param["filename"])
